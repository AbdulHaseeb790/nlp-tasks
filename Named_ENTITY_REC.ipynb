# %%
from transformers import pipeline

# %%
NER=pipeline("ner",aggregation_strategy="simple")
# Out:
# [transformers] No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision 4c53496.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# [transformers] BertForTokenClassification LOAD REPORT from: dbmdz/bert-large-cased-finetuned-conll03-english
# Key                      | Status     |  |
# -------------------------+------------+--+-
# bert.pooler.dense.bias   | UNEXPECTED |  |
# bert.pooler.dense.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
sentences=(
    "Elon Musk founded SpaceX in California in 2002"
)

# %%
print(NER(sentences))
# Out:
# [{'entity_group': 'PER', 'score': np.float32(0.9986783), 'word': 'Elon Musk', 'start': 0, 'end': 9}, {'entity_group': 'ORG', 'score': np.float32(0.99842286), 'word': 'SpaceX', 'start': 18, 'end': 24}, {'entity_group': 'LOC', 'score': np.float32(0.9995946), 'word': 'California', 'start': 28, 'end': 38}]

# %%
sentences=(
    "iam Haseeb and i live in dadu i was born in 2005-05-5"
)

# %%
print(NER(sentences))
# Out:
# [{'entity_group': 'PER', 'score': np.float32(0.5158655), 'word': 'i', 'start': 0, 'end': 1}, {'entity_group': 'PER', 'score': np.float32(0.98828524), 'word': 'Haseeb', 'start': 4, 'end': 10}]
